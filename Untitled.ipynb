# %%
import pandas as pd

# %%
data = pd.read_csv('FullerData_CUReviews_FA22.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Dept  Number                                        Course_Name  \
# 0           0  AAS    2130             Introduction to Asian American History
# 1           1   CS    4701               Practicum in Artificial Intelligence
# 2           2   CS    4780                   Introduction to Machine Learning
# 3           3  DEA    4500  Policy Meets Design: High-Impact Facilities of...
# 4           4  EAS    1600                              Environmental Physics
#
#    Professor_x Start_Time End_Time        Location  \
# 0  Derek Chang    11:25AM  12:40PM  To Be Assigned
# 1  Bart Selman        NaN      NaN             NaN
# 2   Anil Damle    09:40AM  10:55AM  To Be Assigned
# 3   Rana Zadeh    02:45PM  04:00PM  To Be Assigned
# 4   Susan Riha        NaN      NaN  To Be Assigned
#
#                                          Description  \
# 0  An introductory history of Chinese, Japanese, ...
# 1  Artificial Intelligence project class. Possibl...
# ...

# %%
data[data['Pre/coreqs'].str.contains('CS')==True]
# Out:
#       Unnamed: 0   Dept  Number                                  Course_Name  \
# 1              1     CS    4701         Practicum in Artificial Intelligence
# 2              2     CS    4780             Introduction to Machine Learning
# 8              8    ECE    2300      Digital Logic and Computer Organization
# 9              9    ECE    2400                 Computer Systems Programming
# 10            10    ECE    2720                   Data Science for Engineers
# ...          ...    ...     ...                                          ...
# 3920        3920  PLHRT    3500           Principles of Vegetable Production
# 3943        3943  PLSCI    5190      Cannabis: Biology, Society and Industry
# 3953        3953  PLSCS    3630     Soil Genesis, Classification, and Survey
# 3958        3958  PLSCS    3210  Soil and Crop Management for Sustainability
# 4046        4046  STSCI    5740             Data Mining and Machine Learning
#
# ...

# %%
data[data['Pre/coreqs'].str.contains('CS')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a8822aa9bb76> in <module>
# ----> 1 data[data['Pre/coreqs'].str.contains('CS')]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values
