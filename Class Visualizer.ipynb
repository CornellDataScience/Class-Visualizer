# %%
import pandas as pd
import numpy as np

# %%
# import urllib library
from urllib.request import urlopen
  
# import json
import json
# store the URL in url as 
# parameter for urlopen
url = "https://classes.cornell.edu/api/2.0/search/classes.json?roster=SP22&subject=CS" # get SP 22 CS classes
  
# store the response of URL
response = urlopen(url)
  
# storing the JSON response 
# from url in data
data_json = json.loads(response.read())
  
# print the json response
print(data_json)
# Out:
# {'status': 'success', 'data': {'classes': [{'strm': 2811, 'crseId': 358526, 'crseOfferNbr': 1, 'subject': 'CS', 'catalogNbr': '1110', 'titleShort': 'Intro Computing Using Python', 'titleLong': 'Introduction to Computing Using Python', 'enrollGroups': [{'classSections': [{'ssrComponent': 'LEC', 'ssrComponentLong': 'Lecture', 'section': '001', 'classNbr': 10049, 'meetings': [{'classMtgNbr': 1, 'timeStart': '09:05AM', 'timeEnd': '09:55AM', 'startDt': '01/24/2022', 'endDt': '05/10/2022', 'instructors': [{'instrAssignSeq': 10, 'netid': 'awb93', 'firstName': 'Anne', 'middleName': '', 'lastName': 'Bracy'}, {'instrAssignSeq': 1, 'netid': 'ljl2', 'firstName': 'Lillian', 'middleName': '', 'lastName': 'Lee'}], 'pattern': 'TR', 'facilityDescr': 'Bailey Hall 101', 'bldgDescr': 'Bailey Hall', 'facilityDescrshort': 'BLY101', 'meetingTopicDescription': ''}], 'notes': [{'classNotesSeq': 1, 'descrlong': '200 seats are reserved for freshmen. Additional seats are available to all other students. All students (not just engineers!) may opt to enroll in a 1-credit Academic Excellence Workshop (AEW) to be taken in conjunction with this course. AEWs are weekly collaborative problem-solving workshops designed to enhance student understanding of course material. AEWs are facilitated by upper-level engineering students. They are graded S/U based on attendance. In order to attend an AEW, you must enroll in an AEW section, listed under course number ENGRG 1010.'}], 'campus': 'MAIN', 'campusDescr': 'Ithaca', 'location': 'ITH', 'locationDescr': 'Ithaca, NY (Main Campus)', 'startDt': '01/24/2022', 'endDt': '05/21/2022', 'addConsent': 'N', 'addConsentDescr': 'No Special Consent Required', 'isComponentGraded': True, 'instructionMode': 'P', 'instrModeDescrshort': 'In Person', 'instrModeDescr': 'In Person', 'topicDescription': '', 'exploreCriteriaIds': [], 'materials': []}, {'ssrComponent': 'DIS', 'ssrComponentLong': 'Discussion', 'section': '201', 'classNbr': 10050, 'meetings': [{'classMtgNbr': 1, 'timeStart': '11:20AM', 'timeEnd': '12:10PM', 'startDt': '01/24/2022', 'endDt': '05/10/2022', 'instructors': [{'instrAssignSeq': 7, 'netid': 'awb93', 'firstName': 'Anne', 'middleName': '', 'lastName': 'Bracy'}, {'instrAssignSeq': 1, 'netid': 'ljl2', 'firstName': 'Lillian', 'middleName': '', 'lastName': 'Lee'}], 'pattern': 'T', 'facilityDescr': 'Phillips Hall 318', 'bldgDescr': 'Phillips Hall', 'facilityDescrshort': 'PHL318', 'meetingTopicDescription': ''}], 'notes': [], 'campus': 'MAIN', 'campusDescr': 'Ithaca', 'location': 'ITH', 'locationDescr': 'Ithaca, NY (Main Campus)', 'startDt': '01/24/2022', 'endDt': '05/21/2022', 'addConsent': 'N', 'addConsentDescr': 'No Special Consent Required', 'isComponentGraded': False, 'instructionMode': 'P', 'instrModeDescrshort': 'In Person', 'instrModeDescr': 'In Person', 'topicDescription': '', 'exploreCriteriaIds': [], 'materials': []}, {'ssrComponent': 'DIS', 'ssrComponentLong': 'Discussion', 'section': '202', 'classNbr': 10051, 'meetings': [{'classMtgNbr': 1, 'timeStart': '12:25PM', 'timeEnd': '01:15PM', 'startDt': '01/24/2022', 'endDt': '05/10/2022', 'instructors': [{'instrAssignSeq': 8, 'netid': 'awb93', 'firstName': 'Anne', 'middleName': '', 'lastName': 'Bracy'}, {'instrAssignSeq': 1, 'netid': 'ljl2', 'firstName': 'Lillian', 'middleName': '', 'lastName': 'Lee'}], 'pattern': 'T', 'facilityDescr': 'Phillips Hall 318', 'bldgDescr': 'Phillips Hall', 'facilityDescrshort': 'PHL318', 'meetingTopicDescription': ''}], 'notes': [], 'campus': 'MAIN', 'campusDescr': 'Ithaca', 'location': 'ITH', 'locationDescr': 'Ithaca, NY (Main Campus)', 'startDt': '01/24/2022', 'endDt': '05/21/2022', 'addConsent': 'N', 'addConsentDescr': 'No Special Consent Required', 'isComponentGraded': False, 'instructionMode': 'P', 'instrModeDescrshort': 'In Person', 'instrModeDescr': 'In Person', 'topicDescription': '', 'exploreCriteriaIds': [], 'materials': []}, {'ssrComponent': 'DIS', 'ssrComponentLong': 'Discussion', 'section': '203', 'classNbr': 10123, 'meetings ...

# %%
classes = data_json['data']['classes']

# %%
# CS 1110, Bracy, start time, end time, location, description, prereqs/coreqs, semester offered

for subject in ["CS", "INFO", "ECE"]: #, "ECON"]"ENGL", "PHIL"]:
    url = f"https://classes.cornell.edu/api/2.0/search/classes.json?roster=SP22&subject={subject}"
    response = urlopen(url)
  
    # storing the JSON response 
    # from url in data
    data_json = json.loads(response.read())
    
    classes = data_json['data']['classes']
    for class_ in classes:
        if (int(class_['catalogNbr'])) > 5900:
            continue
        #print(class_['subject'] + class_['catalogNbr'] + class_['titleLong'])
        #print(class_)
        obj = class_['enrollGroups'][0]['classSections'][0]['meetings'][0]['instructors'][0]
        #print(obj)
        print(obj['firstName'] + ' ' + obj['middleName'] + ' ' + obj['lastName'])
# Out:
# Anne  Bracy
# Kit-Yee Daisy  Fan
# Kit-Yee Daisy  Fan
# Craig C. Frey
# Royal  Westwater
# Jon M. Kleinberg
# Sumanta  Basu
# Shaun B. Nichols
# Walker Mcmillan White
# Ronald  DiNapoli
# Michael Ryan Clarkson
# Michael Ryan Clarkson
# Kyle J. Harms
# Anke  van Zuylen
# Nate  Foster
# Walker Mcmillan White
# Anne  Bracy
# Nils  Napp
# Dexter  Kozen
# Andrew C. Myers
# Andrew C. Myers
# Walker Mcmillan White
# Michael Ryan Clarkson
# David S. Bindel
# Robbert  VanRenesse
# Robbert  VanRenesse
# Bharath  Hariharan
# Kevin Michael Ellis
# Kevin Michael Ellis
# Marten  van Schijndel
# Hadas  Kress-Gazit
# Christopher Matthew De Sa
# Karthik  Sridharan
# Sarah A Dean
# Dexter  Kozen
# Eshan  Chattopadhyay
# Noah  Stephens-Davidowitz
# Robert David Kleinberg
# Cristobal  Cheyre Forestier
# Lillian  Lee
# Kavita  Bala
# Wen  Sun
# Andrew C. Myers
# Andrew C. Myers
# Andrea  Lodi
    url = f"https://classes.cornell.edu/api/2.0/search/classes.json?roster=SP22&subject={subject}"
    response = urlopen(url)
  
    # storing the JSON response 
    # from url in data
    data_json = json.loads(response.read())
    
    classes = data_json['data']['classes']

    for class_ in classes:
        #print(class_)
        if (int(class_['catalogNbr'])) > 5900:
            continue
        #print(class_)
        obj = class_['enrollGroups'][0]['classSections'][0]['meetings'][0]

        obj2 = obj['instructors'][0]
        #print(obj)

        startTime = obj['timeStart']
        endTime = obj['timeEnd']
        location = obj['facilityDescr']
        x = [class_['subject'] , class_['catalogNbr'] , class_['titleLong'], obj2['firstName'] + ' ' + obj2['middleName'] + ' ' + obj2['lastName'], startTime, endTime, location, class_['description'], class_['catalogPrereqCoreq'], class_['catalogWhenOffered']]
        df.append(x)

# %%
df1 = pd.DataFrame(np.array(df))
df1
# Out:
#        0     1                                                  2  \
# 0     CS  1110             Introduction to Computing Using Python
# 1     CS  1112             Introduction to Computing Using MATLAB
# 2     CS  1132                             Short Course in MATLAB
# 3     CS  1133                             Short Course in Python
# 4     CS  1300    Introductory Design and Programming for the Web
# ..   ...   ...                                                ...
# 165  ECE  5772                           Autonomous Mobile Robots
# 166  ECE  5780                 Computer Analysis of Biomed Images
# 167  ECE  5790     Advanced High-Speed and RF Integrated Circuits
# 168  ECE  5840  Introduction to Controlled Fusion: Principles ...
# 169  ECE  5880                                  Energy Seminar II
#
#                               3        4        5                   6  \
# 0                   Anne  Bracy  09:05AM  09:55AM     Bailey Hall 101
# 1            Kit-Yee Daisy  Fan  02:40PM  03:30PM  Hollister Hall B14
# 2            Kit-Yee Daisy  Fan  02:40PM  03:30PM   Phillips Hall 219
# 3                 Craig C. Frey  12:25PM  01:15PM      Upson Hall 142
# 4              Royal  Westwater  11:25AM  12:40PM       Olin Hall 165
# ..                          ...      ...      ...                 ...
# 165          Hadas  Kress-Gazit  09:40AM  10:55AM  Hollister Hall 110
# 166           Anthony P. Reeves  09:40AM  10:55AM   Phillips Hall 307
# 167  Alyosha Christopher Molnar  11:25AM  12:40PM   Phillips Hall 403
# 168             David A. Hammer  11:20AM  12:10PM   Phillips Hall 407
# 169         C. Lindsay Anderson  12:25PM  01:15PM    Kimball Hall B11
#
#                                                      7  \
# 0    Programming and problem solving using Python. ...
# 1    Programming and problem solving using MATLAB. ...
# 2    Introduction to the MATLAB programming languag...
# 3    Introduction to the Python programming languag...
# 4    The World Wide Web is both a technology and a ...
# ..                                                 ...
# 165  Creating robots capable of performing complex ...
# 166  Powerful imaging modalities with attending com...
# 167  Principles of analog integrated circuit design...
# 168  Introduction to the physical principles and va...
# 169  Energy resources, their conversion to electric...
#
#                                                      8                      9
# 0                                                       Fall, Spring, Summer.
# 1    Corequisite: MATH 1110, MATH 1910, or equivalent.          Fall, Spring.
# 2                                                               Fall, Spring.
# 3                                                               Fall, Spring.
# 4                                                               Fall, Spring.
# ..                                                 ...                    ...
# 165                                                                   Spring.
# 166              Prerequisite: ECE 5470 or equivalent.                Spring.
# 167                            Prerequisite: ECE 4530.                Spring.
# 168  Prerequisite: one of the following: PHYS 1112,...                Spring.
# 169                                                                   Spring.
#
# [170 rows x 10 columns]

# %%
df1.to_csv('classes_from_roster.csv')
