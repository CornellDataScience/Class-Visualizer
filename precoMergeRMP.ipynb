# %%
import pandas as pd
import numpy as np

# %%
class_roster = pd.read_csv("Classes_With_Medians.csv")
rmp_data = pd.read_csv("RMP/RMP.csv")
medians= pd.read_csv("Cornell_Median_Grades.csv")

# %%
semesterdict = {"FA21":0, 'SP21':1, 'FA20':2, 'SP20':3, 'FA19':4,'SP19':5,'FA18':6,'SP18':7,'FA17':8,'SP17':9,'FA16':10}

# %%
#Data cleaning for medians
medians['Semester'] = medians['Semester (Ex: SP21)']
medians = medians.replace({"Semester": semesterdict})
medians = medians.sort_values(by="Semester")
medians = medians.drop_duplicates(subset="Dept + Number", keep="first")
#medians.to_csv("Cleaned_Medians.csv")

# %%
class_roster=class_roster.drop(columns="Unnamed: 0")

# %%
class_roster
# Out:
#        Dept  Number                                        Course_Name  \
# 0       AAS    1100             Introduction to Asian American Studies
# 1       AAS    2620          Introduction to Asian American Literature
# 2       AAS    3030  Asians in the Americas: A Comparative Perspective
# 3       AAS    4020                    U.S. Cultures of War and Empire
# 4       AAS    4550                            Race and the University
# ...     ...     ...                                                ...
# 4539  YORUB    2111                             Intermediate Yoruba II
# 4540  YORUB    3111                                 Advanced Yoruba II
# 4541   ZULU    1116                                 Elementary Zulu II
# 4542   ZULU    2117                               Intermediate Zulu II
# 4543   ZULU    3114                                   Advanced Zulu II
#
#                  Professor Start_Time End_Time                Location  \
# 0              Derek Chang    09:40AM  10:55AM    Rockefeller Hall 132
# 1                Sunn Wong    11:25AM  12:40PM  Goldwin Smith Hall 142
# 2     Viranjini Munasinghe    02:45PM  04:00PM         McGraw Hall B65
# 3        Christine Balance    11:20AM  01:50PM         Sibley Hall B12
# 4              Derek Chang    01:30PM  04:30PM  Goldwin Smith Hall 122
# ...                    ...        ...      ...                     ...
# 4539        Adeolu Ademoyo    09:05AM  09:55AM       Stimson Hall G24B
# 4540        Adeolu Ademoyo    02:45PM  04:00PM                     NaN
# 4541      Angelika Kraemer    11:35AM  12:25PM          To Be Assigned
# 4542      Angelika Kraemer    09:25AM  10:15AM          To Be Assigned
# 4543      Angelika Kraemer    04:00PM  05:15PM          To Be Assigned
#
#                                             Description  \
# 0     This interdisciplinary course offers an introd...
# 1     This course will introduce both a variety of w...
# 2     The common perception of ethnicity is that it ...
# 3     This course examines the history and afterlive...
# 4     What is a university, what does it do, and how...
# ...                                                 ...
# 4539  Intermediate Yoruba II is a follow-up to Inter...
# 4540  This course will help students expand their un...
# 4541  Development of communication skills through di...
# 4542  Students read longer texts from popular media ...
# 4543  Readings may include short stories, a novel, p...
#
#                                     Pre/coreqs  Offered Dept + Number  \
# 0                                          NaN  Spring.      AAS 1100
# 1                                          NaN  Spring.      AAS 2620
# 2                                          NaN  Spring.      AAS 3030
# 3                                          NaN  Spring.      AAS 4020
# 4                                          NaN  Spring.      AAS 4550
# ...                                        ...      ...           ...
# 4539  Prerequisite: YORUB 1108 and YORUB 1109.  Spring.    YORUB 2111
# 4540                 Prerequisite: YORUB 3110.  Spring.    YORUB 3111
# 4541                                       NaN  Spring.     ZULU 1116
# 4542                                       NaN  Spring.     ZULU 2117
# 4543                                       NaN  Spring.     ZULU 3114
#
#      Median Grade Semester (Ex: SP21)  Semester
# 0             NaN                 NaN       NaN
# 1             NaN                 NaN       NaN
# 2             NaN                 NaN       NaN
# 3             NaN                 NaN       NaN
# 4             NaN                 NaN       NaN
# ...           ...                 ...       ...
# 4539          NaN                 NaN       NaN
# 4540          NaN                 NaN       NaN
# 4541          NaN                 NaN       NaN
# 4542          NaN                 NaN       NaN
# 4543          NaN                 NaN       NaN
#
# [4544 rows x 14 columns]

# %%
class_roster[class_roster['Course_Name']=='Problems in Byzantine Art']
# Out:
#        Dept  Number                Course_Name          Professor Start_Time  \
# 468   ARKEO    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 478   ARKEO    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 524    ARTH    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 536    ARTH    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 1087  CLASS    4752  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 1093  CLASS    7752  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 3010  MEDVL    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 3015  MEDVL    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 3287    NES    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 3297    NES    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 4020  RELST    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 4028  RELST    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 4403  VISST    4351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
# 4407  VISST    6351  Problems in Byzantine Art  Benjamin Anderson    09:05AM
#
#      End_Time                Location  \
# 468   11:00AM  Goldwin Smith Hall G19
# 478   11:00AM  Goldwin Smith Hall G19
# 524   11:00AM  Goldwin Smith Hall G19
# 536   11:00AM  Goldwin Smith Hall G19
# 1087  11:00AM  Goldwin Smith Hall G19
# 1093  11:00AM  Goldwin Smith Hall G19
# 3010  11:00AM  Goldwin Smith Hall G19
# 3015  11:00AM  Goldwin Smith Hall G19
# 3287  11:00AM  Goldwin Smith Hall G19
# 3297  11:00AM  Goldwin Smith Hall G19
# 4020  11:00AM  Goldwin Smith Hall G19
# 4028  11:00AM  Goldwin Smith Hall G19
# 4403  11:00AM  Goldwin Smith Hall G19
# 4407  11:00AM  Goldwin Smith Hall G19
#
#                                             Description Pre/coreqs  Offered  \
# 468   Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 478                Seminar topics rotate each semester.        NaN  Spring.
# 524   Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 536                Seminar topics rotate each semester.        NaN  Spring.
# 1087  Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 1093               Seminar topics rotate each semester.        NaN  Spring.
# 3010  Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 3015               Seminar topics rotate each semester.        NaN  Spring.
# 3287  Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 3297               Seminar topics rotate each semester.        NaN  Spring.
# 4020  Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 4028               Seminar topics rotate each semester.        NaN  Spring.
# 4403  Topic Spring 22: Spiral Relief Columns. In thi...        NaN  Spring.
# 4407               Seminar topics rotate each semester.        NaN  Spring.
#
#      Dept + Number Median Grade Semester (Ex: SP21)  Semester
# 468     ARKEO 4351          NaN                 NaN       NaN
# 478     ARKEO 6351          NaN                 NaN       NaN
# 524      ARTH 4351          NaN                 NaN       NaN
# 536      ARTH 6351          NaN                 NaN       NaN
# 1087    CLASS 4752          NaN                 NaN       NaN
# 1093    CLASS 7752          NaN                 NaN       NaN
# 3010    MEDVL 4351          NaN                 NaN       NaN
# 3015    MEDVL 6351          NaN                 NaN       NaN
# 3287      NES 4351          NaN                 NaN       NaN
# 3297      NES 6351          NaN                 NaN       NaN
# 4020    RELST 4351          NaN                 NaN       NaN
# 4028    RELST 6351          NaN                 NaN       NaN
# 4403    VISST 4351          NaN                 NaN       NaN
# 4407    VISST 6351          NaN                 NaN       NaN

# %%
courses = []
for row in class_roster.to_numpy():
    course = row[0]+" " + str(row[1])
    courses.append(course)

# %%
pre_coreqs = []
for row in class_roster.to_numpy():
    preco = row[-6] #normally  -6, if running again then -7
    new_list = []
    #print(type(preco))
    if type(preco) == str or not (np.isnan(preco)):
        
        for course in courses:
            if course in preco:
                new_list.append(course)
    else:
        new_list.append(np.nan)
    pre_coreqs.append(new_list)
#pre_coreqs
class_roster["Pre/Coreqs_Clean"] = pre_coreqs

# %%
full_data = class_roster.merge(rmp_data, left_on='Professor', right_on ="Name", how="outer")

# %%
full_data.shape
# Out:
# (6150, 21)

# %%
full_data['Semester'] = full_data['Semester (Ex: SP21)']
full_data = full_data.replace({"Semester": semesterdict})
full_data = full_data.sort_values(by="Semester")
full_data = full_data.drop_duplicates(subset="Dept + Number", keep="first")
print(full_data.shape)
#full_data = full_data.drop_duplicates(subset="Course_Name", keep="first")
# Out:
# (4545, 21)

# %%
full_data.shape
# Out:
# (4545, 21)

# %%
#full_data=full_data.drop(columns=["Unnamed: 0"])

# %%
full_data
# Out:
#        Dept  Number                                        Course_Name  \
# 34      AEM  2010.0  Spreadsheet Modeling for Management and Economics
# 2723   FREN  2090.0  French Intermediate Composition and Conversati...
# 2724   FREN  2095.0  French Intermediate Composition and Conversati...
# 1797  PSYCH  3420.0  Human Perception: Application to Computer Grap...
# 1788   PHIL  2310.0                    Introduction to Deductive Logic
# ...     ...     ...                                                ...
# 4540   WRIT  2101.0         Responding to Writing: Theory and Pedagogy
# 4541  YORUB  1109.0                          Introduction to Yoruba II
# 4542  YORUB  2111.0                             Intermediate Yoruba II
# 4543  YORUB  3111.0                                 Advanced Yoruba II
# 4544    NaN     NaN                                                NaN
#
#            Professor Start_Time End_Time                Location  \
# 34      Reza Moghimi    01:00PM  02:15PM         Malott Hall 406
# 2723  Flavien Glidja    09:05AM  09:55AM           Uris Hall 369
# 2724   Claire Menard    10:10AM  11:00AM  Goldwin Smith Hall 156
# 1797     David Field    11:25AM  12:40PM         Malott Hall 253
# 1788    Harold Hodes    01:30PM  02:20PM  Goldwin Smith Hall 142
# ...              ...        ...      ...                     ...
# 4540   Kate Navickas    04:30PM  06:00PM    Rockefeller Hall 127
# 4541  Adeolu Ademoyo    10:10AM  11:00AM          To Be Assigned
# 4542  Adeolu Ademoyo    09:05AM  09:55AM       Stimson Hall G24B
# 4543  Adeolu Ademoyo    02:45PM  04:00PM                     NaN
# 4544             NaN        NaN      NaN                     NaN
#
#                                             Description  \
# 34    This course will place a strong emphasis on ap...
# 2723  This intermediate-level course is designed for...
# 2724  This advanced-intermediate course is highly re...
# 1797  Our present technology allows us to transmit a...
# 1788  Covers sentential languages, the truth-functio...
# ...                                                 ...
# 4540  This course introduces students to scholarship...
# 4541  A two-semester beginner's course in Yoruba Lan...
# 4542  Intermediate Yoruba II is a follow-up to Inter...
# 4543  This course will help students expand their un...
# 4544                                                NaN
#
#                                              Pre/coreqs        Offered  ...  \
# 34                                                  NaN  Fall, Spring.  ...
# 2723  Prerequisite: FREN 1230, LPF score 56-64, or S...  Fall, Spring.  ...
# 2724  Prerequisite: FREN 2070, FREN 2080, or FREN 20...  Fall, Spring.  ...
# 1797                                                NaN        Spring.  ...
# 1788                                                NaN  Fall, spring.  ...
# ...                                                 ...            ...  ...
# 4540                                                NaN        Spring.  ...
# 4541                                                NaN        Spring.  ...
# 4542           Prerequisite: YORUB 1108 and YORUB 1109.        Spring.  ...
# 4543                          Prerequisite: YORUB 3110.        Spring.  ...
# 4544                                                NaN            NaN  ...
#
#      Median Grade Semester (Ex: SP21) Semester        Pre/Coreqs_Clean  \
# 34             A-                FA21      0.0                   [nan]
# 2723           A-                FA21      0.0             [FREN 1230]
# 2724            A                FA21      0.0  [FREN 2080, FREN 2090]
# 1797           A-                FA21      0.0                   [nan]
# 1788           A-                FA21      0.0                   [nan]
# ...           ...                 ...      ...                     ...
# 4540          NaN                 NaN      NaN                   [nan]
# 4541          NaN                 NaN      NaN                   [nan]
# 4542          NaN                 NaN      NaN            [YORUB 1109]
# 4543          NaN                 NaN      NaN                      []
# 4544          NaN                 NaN      NaN                     NaN
#
#              ID            Name Number_of_Ratings  Average_Rating  Difficulty  \
# 34    2372836.0    Reza Moghimi               4.0             5.0         2.3
# 2723  1275803.0  Flavien Glidja              19.0             3.4         3.6
# 2724        NaN             NaN               NaN             NaN         NaN
# 1797   539606.0     David Field               8.0             4.2         3.0
# 1788   199658.0    Harold Hodes              34.0             2.5         3.9
# ...         ...             ...               ...             ...         ...
# 4540        NaN             NaN               NaN             NaN         NaN
# 4541  1515016.0  Adeolu Ademoyo               5.0             4.1         1.2
# 4542  1515016.0  Adeolu Ademoyo               5.0             4.1         1.2
# 4543  1515016.0  Adeolu Ademoyo               5.0             4.1         1.2
# 4544  2510713.0  Mustafa Abadan               0.0             0.0         0.0
#
#       Take Again
# 34      100.0000
# 2723     27.2727
# 2724         NaN
# 1797    100.0000
# 1788     20.0000
# ...          ...
# 4540         NaN
# 4541     -1.0000
# 4542     -1.0000
# 4543     -1.0000
# 4544     -1.0000
#
# [4545 rows x 21 columns]

# %%
full_data.to_csv("Full_Data.csv")
