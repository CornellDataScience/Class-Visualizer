# %%
import pandas as pd
import numpy as np

# %%
class_roster = pd.read_csv("Classes_With_Medians.csv")
rmp_data = pd.read_csv("RMP/RMP.csv")
medians= pd.read_csv("Cornell_Median_Grades.csv")

# %%
semesterdict = {"FA21":0, 'SP21':1, 'FA20':2, 'SP20':3, 'FA19':4,'SP19':5,'FA18':6,'SP18':7,'FA17':8,'SP17':9,'FA16':10}

# %%
#Data cleaning for medians
medians['Semester'] = medians['Semester (Ex: SP21)']
medians = medians.replace({"Semester": semesterdict})
medians = medians.sort_values(by="Semester")
medians = medians.drop_duplicates(subset="Dept + Number", keep="first")
medians.to_csv("Cleaned_Medians.csv")

# %%
courses = []
for row in class_roster.to_numpy():
    course = row[1]+" " + str(row[2])
    courses.append(course)

# %%
pre_coreqs = []
for row in class_roster.to_numpy():
    preco = row[-7] #normally negative 6, if running again then -7
    new_list = []
    #print(type(preco))
    if type(preco) == str or not (np.isnan(preco)):
        
        for course in courses:
            if course in preco:
                new_list.append(course)
    else:
        new_list.append(np.nan)
    pre_coreqs.append(new_list)
#pre_coreqs
class_roster["Pre/Coreqs"] = pre_coreqs

# %%
full_data = class_roster.merge(rmp_data, left_on='Professor', right_on ="Name", how="outer")

# %%
full_data
# Out:
#       Unnamed: 0 Dept  Number                                   Course_Name  \
# 0            0.0   CS  1110.0        Introduction to Computing Using Python
# 1           16.0   CS  3410.0  Computer System Organization and Programming
# 2            1.0   CS  1112.0        Introduction to Computing Using MATLAB
# 3            2.0   CS  1132.0                        Short Course in MATLAB
# 4            3.0   CS  1133.0                        Short Course in Python
# ...          ...  ...     ...                                           ...
# 2983         NaN  NaN     NaN                                           NaN
# 2984         NaN  NaN     NaN                                           NaN
# 2985         NaN  NaN     NaN                                           NaN
# 2986         NaN  NaN     NaN                                           NaN
# 2987         NaN  NaN     NaN                                           NaN
#
#               Professor Start_Time End_Time            Location  \
# 0            Anne Bracy    09:05AM  09:55AM     Bailey Hall 101
# 1            Anne Bracy    11:20AM  12:10PM       Uris Hall G01
# 2     Kit-Yee Daisy Fan    02:40PM  03:30PM  Hollister Hall B14
# 3     Kit-Yee Daisy Fan    02:40PM  03:30PM   Phillips Hall 219
# 4            Craig Frey    12:25PM  01:15PM      Upson Hall 142
# ...                 ...        ...      ...                 ...
# 2983                NaN        NaN      NaN                 NaN
# 2984                NaN        NaN      NaN                 NaN
# 2985                NaN        NaN      NaN                 NaN
# 2986                NaN        NaN      NaN                 NaN
# 2987                NaN        NaN      NaN                 NaN
#
#                                             Description  \
# 0     Programming and problem solving using Python. ...
# 1     Introduction to computer organization, systems...
# 2     Programming and problem solving using MATLAB. ...
# 3     Introduction to the MATLAB programming languag...
# 4     Introduction to the Python programming languag...
# ...                                                 ...
# 2983                                                NaN
# 2984                                                NaN
# 2985                                                NaN
# 2986                                                NaN
# 2987                                                NaN
#
#                                              Pre/coreqs  ... Median Grade  \
# 0                                                   NaN  ...           B+
# 1     Prerequisite: CS 2110 or equivalent programmin...  ...           B+
# 2     Corequisite: MATH 1110, MATH 1910, or equivalent.  ...            B
# 3                                                   NaN  ...          NaN
# 4                                                   NaN  ...          NaN
# ...                                                 ...  ...          ...
# 2983                                                NaN  ...          NaN
# 2984                                                NaN  ...          NaN
# 2985                                                NaN  ...          NaN
# 2986                                                NaN  ...          NaN
# 2987                                                NaN  ...          NaN
#
#      Semester (Ex: SP21) Semester Pre/Coreqs         ID           Name  \
# 0                   FA21      0.0         []  2109847.0     Anne Bracy
# 1                   FA21      0.0         []  2109847.0     Anne Bracy
# 2                   FA21      0.0         []        NaN            NaN
# 3                    NaN      NaN         []        NaN            NaN
# 4                    NaN      NaN         []  2555662.0     Craig Frey
# ...                  ...      ...        ...        ...            ...
# 2983                 NaN      NaN        NaN  1403262.0  Thomas Zittel
# 2984                 NaN      NaN        NaN  2384073.0  Sasa Zivkovic
# 2985                 NaN      NaN        NaN   951234.0   Jeffrey Zorn
# 2986                 NaN      NaN        NaN  2090822.0   Brad Zukovic
# 2987                 NaN      NaN        NaN  2171095.0   David Zywina
#
#       Number_of_Ratings Average_Rating  Difficulty  Take Again
# 0                  43.0            3.0         4.0        52.5
# 1                  43.0            3.0         4.0        52.5
# 2                   NaN            NaN         NaN         NaN
# 3                   NaN            NaN         NaN         NaN
# 4                   2.0            4.5         1.5       100.0
# ...                 ...            ...         ...         ...
# 2983                1.0            3.0         2.0        -1.0
# 2984                2.0            2.5         4.5        50.0
# 2985                6.0            4.5         3.2       100.0
# 2986                1.0            4.0         1.0       100.0
# 2987               11.0            4.6         2.9       100.0
#
# [2988 rows x 22 columns]

# %%
full_data.columns
# Out:
# Index(['Unnamed: 0', 'Dept', 'Number', 'Course_Name', 'Professor',
#        'Start_Time', 'End_Time', 'Location', 'Description', 'Pre/coreqs',
#        'Offered', 'Dept + Number', 'Median Grade', 'Semester (Ex: SP21)',
#        'Semester', 'Pre/Coreqs', 'ID', 'Name', 'Number_of_Ratings',
#        'Average_Rating', 'Difficulty', 'Take Again'],
#       dtype='object')

# %%
full_data['Semester'] = full_data['Semester (Ex: SP21)']
full_data = full_data.replace({"Semester": semesterdict})
full_data = full_data.sort_values(by="Semester")
full_data = full_data.drop_duplicates(subset="Dept + Number", keep="first")
full_data = full_data.drop_duplicates(subset="Course_Name", keep="first")

# %%
full_data=full_data.drop(columns=["Unnamed: 0"])

# %%
full_data.drop
# Out:
#      Dept  Number                                        Course_Name  \
# 0      CS  1110.0             Introduction to Computing Using Python
# 129  INFO  3450.0                  Human-Computer Interaction Design
# 152  INFO  4940.0              Special Topics in Information Science
# 169   ECE  2100.0  Introduction to Circuits for Electrical and Co...
# 508   AEM  3205.0               Ethics in Business and Organizations
# ..    ...     ...                                                ...
# 914   BME  6260.0  Optical Microscopy and Fluorescence Methods fo...
# 915   BME  6410.0                  Cell and Molecular Mechanobiology
# 916   BME  7030.0               Graduate Student Teaching Experience
# 917   BME  7130.0                           Core Concepts in Disease
# 918   NaN     NaN                                                NaN
#
#            Professor Start_Time End_Time                   Location  \
# 0         Anne Bracy    09:05AM  09:55AM            Bailey Hall 101
# 129        Qian Yang    01:30PM  02:20PM         Hollister Hall B14
# 152  Sharlane Cleare    01:00PM  02:15PM  Frank H T Rhodes Hall 253
# 169     Carl Poitras    10:10AM  11:00AM          Phillips Hall 219
# 508       John Doris    09:40AM  10:55AM            Malott Hall 251
# ..               ...        ...      ...                        ...
# 914    Warren Zipfel    01:30PM  02:20PM             Weill Hall 224
# 915   Jan Lammerding    09:40AM  10:55AM             Weill Hall 224
# 916   Jan Lammerding        NaN      NaN             To Be Assigned
# 917        Nate Cira    11:25AM  12:40PM             Weill Hall 226
# 918              NaN        NaN      NaN                        NaN
#
#                                            Description  \
# 0    Programming and problem solving using Python. ...
# 129  This course focuses on user experience design ...
# 152  Study of topics not currently covered in INFO ...
# 169  This course is an introduction to electronic c...
# 508  This course will survey ethical problems that ...
# ..                                                 ...
# 914  BME 6260 covers the fundamental optics, photop...
# 915  Mechanobiology describes how cells and tissues...
# 916  Guided individual experience in laboratory ins...
# 917  Most diseases emerge due to a relative small n...
# 918                                                NaN
#
#                                             Pre/coreqs                Offered  \
# 0                                                  NaN  Fall, Spring, Summer.
# 129                                                NaN  Fall, Spring, Summer.
# 152                                                NaN          Fall, Spring.
# 169  Prerequisite: MATH 1920 or PHYS 1112. Corequis...          Fall, Spring.
# 508              Prerequisite: AEM 2200 or equivalent.          Fall, Spring.
# ..                                                 ...                    ...
# 914  Prerequisite: physics, biology and calculus. Y...                Spring.
# 915  Prerequisite: BIOMG 1350 or equivalent, BME 30...                Spring.
# 916                                                NaN          Fall, Spring.
# 917                Prerequisite: introductory biology.                Spring.
# 918                                                NaN                    NaN
#
#      ... Median Grade Semester (Ex: SP21) Semester  Pre/Coreqs         ID  \
# 0    ...           B+                FA21      0.0          []  2109847.0
# 129  ...            A                FA21      0.0          []        NaN
# 152  ...           A+                FA21      0.0          []        NaN
# 169  ...           A-                FA21      0.0          []  1825700.0
# 508  ...            A                FA21      0.0          []        NaN
# ..   ...          ...                 ...      ...         ...        ...
# 914  ...          NaN                 NaN      NaN  [BME 6260]        NaN
# 915  ...          NaN                 NaN      NaN          []        NaN
# 916  ...          NaN                 NaN      NaN          []        NaN
# 917  ...          NaN                 NaN      NaN          []        NaN
# 918  ...          NaN                 NaN      NaN         NaN  2510713.0
#
#                Name Number_of_Ratings  Average_Rating  Difficulty  Take Again
# 0        Anne Bracy              43.0             3.0         4.0     52.5000
# 129             NaN               NaN             NaN         NaN         NaN
# 152             NaN               NaN             NaN         NaN         NaN
# 169    Carl Poitras              36.0             4.1         3.3     87.8788
# 508             NaN               NaN             NaN         NaN         NaN
# ..              ...               ...             ...         ...         ...
# 914             NaN               NaN             NaN         NaN         NaN
# 915             NaN               NaN             NaN         NaN         NaN
# 916             NaN               NaN             NaN         NaN         NaN
# 917             NaN               NaN             NaN         NaN         NaN
# 918  Mustafa Abadan               0.0             0.0         0.0     -1.0000
#
# [713 rows x 21 columns]

# %%
full_data.to_csv("Full_Data.csv")
