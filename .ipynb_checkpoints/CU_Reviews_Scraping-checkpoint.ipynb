# %%
import requests
import pandas as pd

# %%
df = pd.read_csv('Full_Data.csv')
df.head()
# Out:
#    Unnamed: 0   Dept  Number  \
# 0          34    AEM  2010.0
# 1        2512   FREN  2090.0
# 2        2513   FREN  2095.0
# 3        1590  PSYCH  3420.0
# 4        1581   PHIL  2310.0
#
#                                          Course_Name       Professor  \
# 0  Spreadsheet Modeling for Management and Economics    Reza Moghimi
# 1  French Intermediate Composition and Conversati...  Flavien Glidja
# 2  French Intermediate Composition and Conversati...   Claire Menard
# 3  Human Perception: Application to Computer Grap...     David Field
# 4                    Introduction to Deductive Logic    Harold Hodes
#
#   Start_Time End_Time                Location  \
# 0    01:00PM  02:15PM         Malott Hall 406
# 1    09:05AM  09:55AM           Uris Hall 369
# 2    10:10AM  11:00AM  Goldwin Smith Hall 156
# 3    11:25AM  12:40PM         Malott Hall 253
# 4    01:30PM  02:20PM  Goldwin Smith Hall 142
#
#                                          Description  \
# 0  This course will place a strong emphasis on ap...
# 1  This intermediate-level course is designed for...
# 2  This advanced-intermediate course is highly re...
# 3  Our present technology allows us to transmit a...
# 4  Covers sentential languages, the truth-functio...
#
#                                           Pre/coreqs  ... Median Grade  \
# 0                                                NaN  ...           A-
# 1  Prerequisite: FREN 1230, LPF score 56-64, or S...  ...           A-
# 2  Prerequisite: FREN 2070, FREN 2080, or FREN 20...  ...            A
# 3                                                NaN  ...           A-
# 4                                                NaN  ...           A-
#
#   Semester (Ex: SP21) Semester            Pre/Coreqs_Clean         ID  \
# 0                FA21      0.0                       [nan]  2372836.0
# 1                FA21      0.0               ['FREN 1230']  1275803.0
# 2                FA21      0.0  ['FREN 2080', 'FREN 2090']        NaN
# 3                FA21      0.0                       [nan]   539606.0
# 4                FA21      0.0                       [nan]   199658.0
#
#              Name  Number_of_Ratings Average_Rating  Difficulty  Take Again
# 0    Reza Moghimi                4.0            5.0         2.3    100.0000
# 1  Flavien Glidja               19.0            3.4         3.6     27.2727
# 2             NaN                NaN            NaN         NaN         NaN
# 3     David Field                8.0            4.2         3.0    100.0000
# 4    Harold Hodes               34.0            2.5         3.9     20.0000
#
# [5 rows x 22 columns]

# %%
data = df.to_numpy()

url = 'https://www.cureviews.org/v2/getCourseByInfo/'

difficulty = []
ratings = []
workloads = []

for val in data:

    try:
        sub = val[1].lower()
        num = int(val[2])
        myobj = {'number': num, 'subject': sub}

        res = requests.post(url, json = myobj).json()['result']

        diff = res['classDifficulty']
        rating = res['classRating']
        workload = res['classWorkload']
        
    except:
        diff = None
        rating = None
        workload = None
    
    difficulty += [diff]
    ratings += [rating]
    workloads += [workload]

# %%
len(workloads)
# Out:
# 4328

# %%
df.shape
# Out:
# (4328, 22)

# %%
df['CU_Reviews_Difficulty'] = difficulty
df['CU_Reviews_Rating'] = ratings
df['CU_Reviews_Workload'] = workloads

# %%
df.head()
# Out:
#    Unnamed: 0   Dept  Number  \
# 0          34    AEM  2010.0
# 1        2512   FREN  2090.0
# 2        2513   FREN  2095.0
# 3        1590  PSYCH  3420.0
# 4        1581   PHIL  2310.0
#
#                                          Course_Name       Professor  \
# 0  Spreadsheet Modeling for Management and Economics    Reza Moghimi
# 1  French Intermediate Composition and Conversati...  Flavien Glidja
# 2  French Intermediate Composition and Conversati...   Claire Menard
# 3  Human Perception: Application to Computer Grap...     David Field
# 4                    Introduction to Deductive Logic    Harold Hodes
#
#   Start_Time End_Time                Location  \
# 0    01:00PM  02:15PM         Malott Hall 406
# 1    09:05AM  09:55AM           Uris Hall 369
# 2    10:10AM  11:00AM  Goldwin Smith Hall 156
# 3    11:25AM  12:40PM         Malott Hall 253
# 4    01:30PM  02:20PM  Goldwin Smith Hall 142
#
#                                          Description  \
# 0  This course will place a strong emphasis on ap...
# 1  This intermediate-level course is designed for...
# 2  This advanced-intermediate course is highly re...
# 3  Our present technology allows us to transmit a...
# 4  Covers sentential languages, the truth-functio...
#
#                                           Pre/coreqs  ...  \
# 0                                                NaN  ...
# 1  Prerequisite: FREN 1230, LPF score 56-64, or S...  ...
# 2  Prerequisite: FREN 2070, FREN 2080, or FREN 20...  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#              Pre/Coreqs_Clean         ID            Name Number_of_Ratings  \
# 0                       [nan]  2372836.0    Reza Moghimi               4.0
# 1               ['FREN 1230']  1275803.0  Flavien Glidja              19.0
# 2  ['FREN 2080', 'FREN 2090']        NaN             NaN               NaN
# 3                       [nan]   539606.0     David Field               8.0
# 4                       [nan]   199658.0    Harold Hodes              34.0
#
#    Average_Rating Difficulty  Take Again CU_Reviews_Difficulty  \
# 0             5.0        2.3    100.0000              1.444444
# 1             3.4        3.6     27.2727              2.000000
# 2             NaN        NaN         NaN              3.000000
# 3             4.2        3.0    100.0000              2.200000
# 4             2.5        3.9     20.0000                   NaN
#
#    CU_Reviews_Rating  CU_Reviews_Workload
# 0              4.375             1.875000
# 1              4.000             2.500000
# 2              4.000                  NaN
# 3              5.000             1.333333
# 4                NaN                  NaN
#
# [5 rows x 25 columns]

# %%
df.to_csv('FullerData_CUReviews.csv', index=None)
