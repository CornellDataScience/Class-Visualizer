# %%
import requests
import pandas as pd

# %%
df = pd.read_csv('Full_Data_SP23.csv')
df.head()
# Out:
#    Unnamed: 0   Dept  Number                                Course_Name  \
# 0           0    AAS  1100.0     Introduction to Asian American Studies
# 1           1    AAS  4950.0                          Independent Study
# 2           2    AAS  7200.0         Directed Graduate Individual Study
# 3           3  ANTHR  6025.0                 Proseminar in Anthropology
# 4           4    AAS  2620.0  Introduction to Asian American Literature
#
#               Professor Start_Time End_Time        Location  \
# 0  Viranjini Munasinghe    02:55PM  04:10PM  To Be Assigned
# 1  Viranjini Munasinghe        NaN      NaN             NaN
# 2  Viranjini Munasinghe        NaN      NaN             NaN
# 3  Viranjini Munasinghe    04:30PM  07:30PM  To Be Assigned
# 4     Juliana Hu Pegues    11:25AM  12:40PM  To Be Assigned
#
#                                          Description Pre/coreqs  ... notes  \
# 0  This interdisciplinary course offers an introd...        NaN  ...   NaN
# 1  Independent reading course in topics not cover...        NaN  ...   NaN
# 2                                                NaN        NaN  ...   NaN
# 3  This course explores advanced topics in anthro...        NaN  ...   NaN
# 4  This course will introduce both a variety of w...        NaN  ...   NaN
#
#   SemesterN Pre/Coreqs_Clean  ID Name Number_of_Ratings  Average_Rating  \
# 0       NaN            [nan] NaN  NaN               NaN             NaN
# 1       NaN            [nan] NaN  NaN               NaN             NaN
# 2       NaN            [nan] NaN  NaN               NaN             NaN
# 3       NaN            [nan] NaN  NaN               NaN             NaN
# 4       NaN            [nan] NaN  NaN               NaN             NaN
#
#   Difficulty  Take Again Semester
# 0        NaN         NaN      NaN
# 1        NaN         NaN      NaN
# 2        NaN         NaN      NaN
# 3        NaN         NaN      NaN
# 4        NaN         NaN      NaN
#
# [5 rows x 27 columns]

# %%
data = df.to_numpy()

url = 'https://www.cureviews.org/v2/getCourseByInfo/'

difficulty = []
ratings = []
workloads = []

for val in data:

    try:
        sub = val[1].lower()
        num = int(val[2])
        myobj = {'number': num, 'subject': sub}

        res = requests.post(url, json = myobj).json()['result']

        diff = res['classDifficulty']
        rating = res['classRating']
        workload = res['classWorkload']
        
    except:
        diff = None
        rating = None
        workload = None
    
    difficulty += [diff]
    ratings += [rating]
    workloads += [workload]

# %%
len(workloads)
# Out:
# 4520

# %%
df.shape
# Out:
# (4520, 27)

# %%
df['CU_Reviews_Difficulty'] = difficulty
df['CU_Reviews_Rating'] = ratings
df['CU_Reviews_Workload'] = workloads

# %%
df.head()
# Out:
#    Unnamed: 0   Dept  Number                                Course_Name  \
# 0           0    AAS  1100.0     Introduction to Asian American Studies
# 1           1    AAS  4950.0                          Independent Study
# 2           2    AAS  7200.0         Directed Graduate Individual Study
# 3           3  ANTHR  6025.0                 Proseminar in Anthropology
# 4           4    AAS  2620.0  Introduction to Asian American Literature
#
#               Professor Start_Time End_Time        Location  \
# 0  Viranjini Munasinghe    02:55PM  04:10PM  To Be Assigned
# 1  Viranjini Munasinghe        NaN      NaN             NaN
# 2  Viranjini Munasinghe        NaN      NaN             NaN
# 3  Viranjini Munasinghe    04:30PM  07:30PM  To Be Assigned
# 4     Juliana Hu Pegues    11:25AM  12:40PM  To Be Assigned
#
#                                          Description Pre/coreqs  ...  ID Name  \
# 0  This interdisciplinary course offers an introd...        NaN  ... NaN  NaN
# 1  Independent reading course in topics not cover...        NaN  ... NaN  NaN
# 2                                                NaN        NaN  ... NaN  NaN
# 3  This course explores advanced topics in anthro...        NaN  ... NaN  NaN
# 4  This course will introduce both a variety of w...        NaN  ... NaN  NaN
#
#   Number_of_Ratings Average_Rating Difficulty Take Again  Semester  \
# 0               NaN            NaN        NaN        NaN       NaN
# 1               NaN            NaN        NaN        NaN       NaN
# 2               NaN            NaN        NaN        NaN       NaN
# 3               NaN            NaN        NaN        NaN       NaN
# 4               NaN            NaN        NaN        NaN       NaN
#
#   CU_Reviews_Difficulty  CU_Reviews_Rating CU_Reviews_Workload
# 0              2.333333                3.0            3.333333
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4              2.000000                4.0            3.000000
#
# [5 rows x 30 columns]

# %%
df.to_csv('FullerData_CUReviews_SP23.csv', index=None)
